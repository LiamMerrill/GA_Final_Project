# %% [markdown]
# # Art Museum Staff Demographics Dashboard: 2015 and 2018

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import category_encoders as ce
import matplotlib.pyplot as pl

# %% [markdown]
# This is a dataset that I compiled beginning in 2014, with support from the Mellon Foundation.  In this initiative, I surveyed on behalf of Mellon several hundred museums in the US to gather demographic data. The data that was submitted comes from their HR systems. I received ~250 excel spreadsheets which were appended into a single dataset in 2015. In 2018, another cycle of data was collected. An anonymized version of the data will be published with the National Archive for Data on Arts and Culture (NADAC), which is part of ICPSR.
#
# In this project, I will prepare the data for analysis, explore the data with visualizations, fit the data to a decision tree, tune the parameters of the decision tree in order to maximize its predictions, explore the data using a partial dependence plot, and fit the data to a gradient boosted model. I will then prepare a python file to be hosted on github with a pickled model, and deploy a dashboard as a web application on streamlit.
#
# - Prep
# - Vis
# - Fit
# - PDP
# - GBM
# - Dash

# %% [markdown]
# ## Prep

# %%
df = pd.read_csv('/Users/liamsweeney/IthakaSR/LS_NADAC_1_29_2022.csv')

# %%
df.head()
# Out:
#                       job_title               job_type  \
# 0      administrative associate  support/administrator
# 1                       curator               curators
# 2              facility manager             facilities
# 3              museum registrar              registrar
# 4  educational programs manager              education
#
#                 eeo_job_c   exemption        employment      ft/pt  \
# 0  administrative support  non-exempt  regular employee  full time
# 1           professionals      exempt  regular employee  full time
# 2           professionals      exempt  regular employee  full time
# 3           professionals      exempt  regular employee  full time
# 4           professionals      exempt  regular employee  full time
#
#             education   race ethnicity  gender  ... Unnamed: 245 Unnamed: 246  \
# 0  bachelor's degree   white        no  female  ...          NaN          NaN
# 1     master's degree  white        no    male  ...          NaN          NaN
# 2     master's degree  white        no  female  ...          NaN          NaN
# 3     master's degree  white        no  female  ...          NaN          NaN
# 4                 phd  white        no  female  ...          NaN          NaN
#
#   Unnamed: 247 Unnamed: 248 Unnamed: 249 Unnamed: 250  Unnamed: 251  \
# 0          NaN          NaN          NaN          NaN           NaN
# 1          NaN          NaN          NaN          NaN           NaN
# 2          NaN          NaN          NaN          NaN           NaN
# 3          NaN          NaN          NaN          NaN           NaN
# 4          NaN          NaN          NaN          NaN           NaN
#
#   Unnamed: 252  Unnamed: 253 Unnamed: 254
# 0          NaN           NaN          NaN
# 1          NaN           NaN          NaN
# 2          NaN           NaN          NaN
# 3          NaN           NaN          NaN
# 4          NaN           NaN          NaN
#
# [5 rows x 255 columns]

# %%
df.dropna(how='all', axis=1)
# Out:
#                           job_title  \
# 0          administrative associate
# 1                           curator
# 2                  facility manager
# 3                  museum registrar
# 4      educational programs manager
# ...                             ...
# 52819                           NaN
# 52820                           NaN
# 52821                           NaN
# 52822                           NaN
# 52823                           NaN
#
#                                                job_type  \
# 0                                 support/administrator
# 1                                              curators
# 2                                            facilities
# 3                                             registrar
# 4                                             education
# ...                                                 ...
# 52819  membership/development (includes event planning)
# 52820                                          curators
# 52821  membership/development (includes event planning)
# 52822  membership/development (includes event planning)
# 52823  museum leadership (includes executive positions)
#
#                     eeo_job_c         exemption        employment  \
# 0      administrative support        non-exempt  regular employee
# 1               professionals            exempt  regular employee
# 2               professionals            exempt  regular employee
# 3               professionals            exempt  regular employee
# 4               professionals            exempt  regular employee
# ...                       ...               ...               ...
# 52819        decline to state  decline to state  decline to state
# 52820        decline to state  decline to state  decline to state
# 52821        decline to state  decline to state  decline to state
# 52822        decline to state  decline to state  decline to state
# 52823        decline to state  decline to state  decline to state
#
#                   ft/pt           education   race ethnicity  gender  ...  \
# 0             full time  bachelor's degree   white        no  female  ...
# 1             full time     master's degree  white        no    male  ...
# 2             full time     master's degree  white        no  female  ...
# 3             full time     master's degree  white        no  female  ...
# 4             full time                 phd  white        no  female  ...
# ...                 ...                 ...    ...       ...     ...  ...
# 52819  decline to state    decline to state  white        no    male  ...
# 52820  decline to state    decline to state  white        no  female  ...
# 52821  decline to state    decline to state  white        no  female  ...
# 52822  decline to state    decline to state  white        no  female  ...
# 52823  decline to state    decline to state  white        no  female  ...
#
#        year affiliation  count   size  anonymized state  zip type  budget  \
# 0      2018         AAM      1    NaN  musuem 296   NaN  NaN  NaN     NaN
# 1      2018         AAM      2    NaN  musuem 296   NaN  NaN  NaN     NaN
# 2      2018         AAM      3    NaN  musuem 296   NaN  NaN  NaN     NaN
# 3      2018         AAM      4    NaN  musuem 296   NaN  NaN  NaN     NaN
# 4      2018         AAM      5    NaN  musuem 296   NaN  NaN  NaN     NaN
# ...     ...         ...    ...    ...         ...   ...  ...  ...     ...
# 52819  2015         AAM  52820  small  musuem 284   NaN  NaN  NaN     NaN
# 52820  2015         AAM  52821  small  musuem 284   NaN  NaN  NaN     NaN
# 52821  2015         AAM  52822  small  musuem 284   NaN  NaN  NaN     NaN
# 52822  2015         AAM  52823  small  musuem 284   NaN  NaN  NaN     NaN
# 52823  2015         AAM  52824  small  musuem 284   NaN  NaN  NaN     NaN
#
#       Unnamed: 254
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 52819          NaN
# 52820          NaN
# 52821          NaN
# 52822          NaN
# 52823          NaN
#
# [52824 rows x 26 columns]

# %%
df.drop("origin_filename", axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/ry/lx4fw4hj4c58xy781z3_7cbm0000gn/T/ipykernel_1628/4256805539.py in <module>
# ----> 1 df.drop("origin_filename", axis = 1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['origin_filename'] not found in axis"

# %%
df.isnull().sum()

# %%
df.dtypes
# Out:
# job_title             object
# job_type              object
# eeo_job_c             object
# exemption             object
# employment            object
# ft_pt                 object
# education             object
# race                  object
# ethnicity             object
# gender                object
# protected             object
# disability            object
# year_of_b             object
# year_of_h             object
# origin_filename       object
# repeat_participant    object
# year                   int64
# affiliation           object
# count                  int64
# size                  object
# anonymized            object
# dtype: object

# %%
grouping_Year = df.groupby(['year'])

# %%
df['year'] = df['year'].apply(str)

# %%
df.dtypes
# Out:
# job_title             object
# job_type              object
# eeo_job_c             object
# exemption             object
# employment            object
# ft_pt                 object
# education             object
# race                  object
# ethnicity             object
# gender                object
# protected             object
# disability            object
# year_of_b             object
# year_of_h             object
# origin_filename       object
# repeat_participant    object
# year                  object
# affiliation           object
# count                  int64
# size                  object
# anonymized            object
# dtype: object

# %%
df.head()
# Out:
#                       job_title               job_type  \
# 0      Administrative Associate  Support/Administrator
# 1                       Curator               Curators
# 2              Facility Manager             Facilities
# 3              Museum Registrar              Registrar
# 4  Educational Programs Manager              Education
#
#                 eeo_job_c   exemption        employment      ft_pt  \
# 0  Administrative Support  Non-exempt  Regular employee  Full time
# 1           Professionals      Exempt  Regular employee  Full time
# 2           Professionals      Exempt  Regular employee  Full time
# 3           Professionals      Exempt  Regular employee  Full time
# 4           Professionals      Exempt  Regular employee  Full time
#
#             education   race ethnicity  gender protected  \
# 0  Bachelor's Degree   White        No  Female        No
# 1     Master's Degree  White        No    Male        No
# 2     Master's Degree  White        No  Female        No
# 3     Master's Degree  White        No  Female        No
# 4                 PhD  White        No  Female        No
#
#                     disability year_of_b year_of_h  \
# 0  Person without a disability      1982      2015
# 1  Person without a disability      1962      2010
# 2  Person without a disability      1982      2015
# 3  Person without a disability      1980      2018
# 4  Person without a disability      1982      2015
#
#                           origin_filename repeat_participant  year  \
# 0  Art Museum of West Virginia University                  0  2018
# 1  Art Museum of West Virginia University                  0  2018
# 2  Art Museum of West Virginia University                  0  2018
# 3  Art Museum of West Virginia University                  0  2018
# 4  Art Museum of West Virginia University                  0  2018
#
#   affiliation  count size  anonymized
# 0         AAM      1  NaN  Musuem 296
# 1         AAM      2  NaN  Musuem 296
# 2         AAM      3  NaN  Musuem 296
# 3         AAM      4  NaN  Musuem 296
# 4         AAM      5  NaN  Musuem 296

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ry/lx4fw4hj4c58xy781z3_7cbm0000gn/T/ipykernel_1071/3677465091.py in <module>
#       1 pd.set_option('display.max_columns', None)
#       2 pd.set_option('display.max_rows', None)
# ----> 3 df("columns")
#
# TypeError: 'DataFrame' object is not callable

# %%
print(df.columns.tolist())
# Out:
# ['job_title', 'job_type', 'eeo_job_c', 'exemption', 'employment', 'ft_pt', 'education', 'race', 'ethnicity', 'gender', 'protected', 'disability', 'year_of_b', 'year_of_h', 'origin_filename', 'repeat_participant', 'year', 'affiliation', 'count', 'size', 'anonymized']

# %%
new_df=df.dropna(how='all', axis=1)

# %%
new_df.columns = new_df.columns.str.replace(' ', '')

# %%
new_df['job_type']=new_df['job_type'].apply(lambda x: x.strip())

# %%
new_df.head()
# Out:
#                       job_title               job_type  \
# 0      Administrative Associate  Support/Administrator
# 1                       Curator               Curators
# 2              Facility Manager             Facilities
# 3              Museum Registrar              Registrar
# 4  Educational Programs Manager              Education
#
#                 eeo_job_c   exemption        employment      ft_pt  \
# 0  Administrative Support  Non-exempt  Regular employee  Full time
# 1           Professionals      Exempt  Regular employee  Full time
# 2           Professionals      Exempt  Regular employee  Full time
# 3           Professionals      Exempt  Regular employee  Full time
# 4           Professionals      Exempt  Regular employee  Full time
#
#             education   race ethnicity  gender protected  \
# 0  Bachelor's Degree   White        No  Female        No
# 1     Master's Degree  White        No    Male        No
# 2     Master's Degree  White        No  Female        No
# 3     Master's Degree  White        No  Female        No
# 4                 PhD  White        No  Female        No
#
#                     disability year_of_b year_of_h  \
# 0  Person without a disability      1982      2015
# 1  Person without a disability      1962      2010
# 2  Person without a disability      1982      2015
# 3  Person without a disability      1980      2018
# 4  Person without a disability      1982      2015
#
#                           origin_filename repeat_participant  year  \
# 0  Art Museum of West Virginia University                  0  2018
# 1  Art Museum of West Virginia University                  0  2018
# 2  Art Museum of West Virginia University                  0  2018
# 3  Art Museum of West Virginia University                  0  2018
# 4  Art Museum of West Virginia University                  0  2018
#
#   affiliation  count size  anonymized
# 0         AAM      1  NaN  Musuem 296
# 1         AAM      2  NaN  Musuem 296
# 2         AAM      3  NaN  Musuem 296
# 3         AAM      4  NaN  Musuem 296
# 4         AAM      5  NaN  Musuem 296

# %%
new_df['job_type'].unique()
# Out:
# array(['Support/Administrator', 'Curators', 'Facilities', 'Registrar',
#        'Education', 'Preparators/Handlers',
#        'Museum Leadership (includes executive positions)',
#        'Visitor Services', 'Decline to state',
#        'Exhibition Design and Construction (includes Fabrication)',
#        'Marketing/Public Relations',
#        'Membership/Development (includes Event Planning)',
#        'Rights/Reproduction (includes Photography)',
#        'Information Technology/Web Development',
#        'Finance/Human Resources', 'Retail and Store', 'Archive/Library',
#        'Security', 'Publication/Editorial', 'Conservators', 'education',
#        'curators', 'decline to state', 'Preparators/handlers',
#        'retail and Store', 'visitor Services', 'preparators/Handlers',
#        'Development', 'security',
#        'rights/Reproduction (includes Photography)',
#        'finance/Human Resources',
#        'membership/Development (includes Event Planning)', 'registrar',
#        'Decline to State', 'FACILITIES', 'MARKETING/PUBLIC RELATIONS',
#        'CURATORS', 'EDUCATION', 'REGISTRAR', 'CONSERVATORS',
#        'RETAIL AND STORE', 'PUBLICATION/EDITORIAL', 'VISITOR SERVICES',
#        'exhibition Design and Construction (includes Fabrication)'],
#       dtype=object)

# %%
grouping_gender_origin=new_df.groupby(['gender', 'origin_filename'])

# %%
new_df['eeo_job_c'].unique()
# Out:
# array(['Administrative Support', 'Professionals',
#        'Executive/Sr Officials & Mgrs', 'Service Workers', 'Technicians',
#        'Laborers & Helpers', 'First/Mid Officials & Mgrs',
#        'Service workers', 'Sales workers', 'Craft workers',
#        'Decline to state', 'Sales Workers', 'Operatives', 'Craft Workers',
#        'Administrative support', 'laborers & helpers',
#        'laborers & Helpers', 'decline to state', 'administrative Support',
#        'service Workers', 'ADministrative Support',
#        'first/Mid Officials & Mgrs', 'sales workers', 'craft workers',
#        'professionals', 'Administrative Support ',
#        'Executive/SR Officials & Mgrs'], dtype=object)

# %%
new_df['exemption']=new_df['exemption'].apply(lambda x: x.strip())

# %%
new_df['exemption'].unique()
# Out:
# array(['Non-exempt', 'Exempt', 'Decline to state', 'Non-Exempt',
#        'non-exempt', 'exempt', 'decline to state', 'Decline to State',
#        'EXEMPT'], dtype=object)

# %%
new_df['employment']=new_df['employment'].apply(lambda x:x.strip())

# %%
new_df['education']=new_df['education'].apply(lambda x:x.strip())

# %%
new_df['ethnicity']=new_df['ethnicity'].apply(lambda x:x.strip())

# %%
new_df['disability']=new_df['disability'].apply(lambda x:x.strip())

# %%
new_df['disability'].unique()
# Out:
# array(['Person without a disability', 'Person with a disability',
#        'Decline to state', 'Decline to State', 'decline to state',
#        'person without a disability', 'Person with a disabilty'],
#       dtype=object)

# %%
new_df['race']=new_df['race'].apply(lambda x: x.strip())

# %%
new_df['race'].unique()
# Out:
# array(['White', 'Black or African American', 'Asian',
#        'Native Hawaiian or Pacific Islander', 'Decline to state',
#        'Two or more races', 'American Indian or Alaskan Native', 'ASIAN',
#        'WHITE', 'Two or More Races', 'white', 'asian',
#        'Two or more Races', 'decline to state',
#        'black or African American', 'American Indian Or Alaskan Native',
#        'Two Or More Races', 'Decline to State'], dtype=object)

# %%
new_df['gender']=new_df['gender'].apply(lambda x: x.strip())

# %%
new_df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Decline to state', 'Non-binary',
#        'Not specified', 'decline to state', 'Not Specified', 'male',
#        'female', 'Decline to State', 'FEMALE', 'MALE'], dtype=object)
